# %% [markdown]
# # Pandas
#
# - https://pandas.pydata.org/
# - Python external library for Data Analysis : Tabular Data format (Excel, CSV, etc.)
# - read_csv : open a csv file by Pandas
# - read_excel : open an excel file by Pandas
# - https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html?highlight=read_csv#pandas.read_csv
# - https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html?highlight=read_excel#pandas.read_excel

# %%
import pandas as pd

# %%
data = pd.read_csv('/kaggle/input/titanic/train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data['Fare']
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %%
data['Age'].fillna(data['Age'].mean(), inplace=True)

# %%
data_fare = data['Fare'].values  # Save column data as NumPy Array

# %%
data_age = data['Age'].values

# %% [markdown]
# - Let us visualize the 'Fare' column!

# %% [markdown]
# # Visualization : Matplotlib Library
#
# - https://matplotlib.org/

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# - You start to define how many subplots are included in your Figure.
# - By using subplots, you can define your figure and your subplots.
# - fig = variable for your overall figure
# - ax (axes) = variable for each subplot
# - figsize = (width, height)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(10, 3))
ax.plot(data_fare)
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 5))
ax[0,0].plot(data_age)
ax[1,1].plot(data_fare)
plt.show()

# %%
ax.shape
# Out:
# (2, 2)

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
ax[0].plot(data_age)
ax[1].plot(data_fare)
plt.show()

# %% [markdown]
# ## Histogram

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))
ax[0].hist(data_age,  bins=20, edgecolor="white", color="green", alpha=0.5)
ax[1].hist(data_fare, bins=20, edgecolor="white")
ax[0].grid()
ax[1].grid()
plt.show()

# %% [markdown]
# ## Boxplot

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(10, 5))
ax[0].boxplot(data_age, vert=False, patch_artist=True)
ax[1].boxplot(data_fare, vert=False, patch_artist=True)
plt.show()

# %% [markdown]
# ----

# %%
import scipy.stats as stats

# %%
stats.skew(data_fare)
# Out:
# 4.7792532923723545

# %%
stats.skew(data_age)
# Out:
# 0.4337562902461274

# %%
stats.kurtosis(data_fare)
# Out:
# 33.20428925264474

# %%
stats.kurtosis(data_age)
# Out:
# 0.9541389157820586
