# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('고려사항.csv',  encoding='cp949')

# %%
print(df)
print(df.shape)
# Out:
#     특성별(1)  특성별(2)   2020  2020.1      2020.2      2020.3 2020.4 2020.5  \
# 0   특성별(1)  특성별(2)    1순위     1순위         1순위         1순위    1순위    1순위
# 1   특성별(1)  특성별(2)  동반 인원  실외 관광지  사람이 몰리는 일시  활동 및 체험 내용  여행 경비  이동 거리
# 2       전체      소계   17.7    10.3        13.4        12.6    8.5   10.0
# 3       성별      남성   17.1    11.3        14.1        12.6    7.8   10.5
# 4       성별      여성   18.3     9.3        12.6        12.6    9.2    9.5
# 5      연령별  15~19세   26.4     7.0         8.6        12.3   11.0   10.6
# 6      연령별     20대   18.2     6.1        14.0        17.4    9.9    9.6
# 7      연령별     30대   18.5    12.3        13.7        12.3    5.8    7.9
# 8      연령별     40대   15.8    10.2        14.6        14.0    6.5    9.7
# 9      연령별     50대   14.3    14.9        14.7        11.8    5.8   10.4
# 10     연령별  60대 이상   18.9     9.0        11.9         9.9   12.1   11.3
# 11     지역별      서울   24.8    15.6        12.9        17.1    4.4    4.7
# ...

# %%
data = df.loc[[0,1,2,3,4,6,16]]
dataa = data.iloc[:,[0,1,2,3,4,5,13,14,15]]
print(dataa)
# Out:
#     특성별(1)  특성별(2)   2020  2020.1      2020.2      2020.3  2020.11  2020.12  \
# 0   특성별(1)  특성별(2)    1순위     1순위         1순위         1순위  1+2+3순위  1+2+3순위
# 1   특성별(1)  특성별(2)  동반 인원  실외 관광지  사람이 몰리는 일시  활동 및 체험 내용    동반 인원   실외 관광지
# 2       전체      소계   17.7    10.3        13.4        12.6     29.2     23.9
# 3       성별      남성   17.1    11.3        14.1        12.6     29.4     25.6
# 4       성별      여성   18.3     9.3        12.6        12.6     28.9     22.3
# 6      연령별     20대   18.2     6.1        14.0        17.4     27.1     16.7
# 16     지역별      대전   19.6     5.9        10.3         9.2     28.8     23.5
#
#        2020.13
# 0      1+2+3순위
# 1   사람이 몰리는 일시
# 2         28.8
# 3         29.9
# 4         27.8
# 6         30.4
# 16        18.4

# %%
df2 = pd.read_csv('매출규모.csv',  encoding='cp949')
print(df2)
# Out:
#     특성별(1)                      특성별(2)     2021   2021.1   2021.2   2021.3  \
# 0   특성별(1)                      특성별(2)  올해 매출규모  올해 매출규모  올해 매출규모  올해 매출규모
# 1   특성별(1)                      특성별(2)    매우 증가       증가      비슷함       감소
# 2       합계                          소계      0.4     11.3     41.0     35.1
# 3    조직형태별                       개인사업체        -     12.5     29.5     37.0
# 4    조직형태별                        회사법인      0.5     11.5     42.0     36.1
# 5    조직형태별                      회사이외법인        -      5.4     52.6     32.6
# 6    조직형태별                       비법인단체        -      7.9     73.5     12.0
# 7   종사자규모별                      10~19인      0.6     10.6     41.7     33.9
# 8   종사자규모별                      20~49인        -     11.7     39.3     37.6
# 9   종사자규모별                      50~99인      0.7     15.4     41.4     34.3
# 10  종사자규모별                     100인 이상        -     10.1     43.6     34.9
# ...

# %%
data2 = df2.loc[[0,1,2,3,7,17]]
dataa2 = data2.iloc[:,[0,1,2,3,4,5,6,16,24]]
print(dataa2)
# Out:
#     특성별(1)        특성별(2)     2021   2021.1   2021.2   2021.3   2021.4  \
# 0   특성별(1)        특성별(2)  올해 매출규모  올해 매출규모  올해 매출규모  올해 매출규모  올해 매출규모
# 1   특성별(1)        특성별(2)    매우 증가       증가      비슷함       감소    매우 감소
# 2       합계            소계      0.4     11.3     41.0     35.1     12.2
# 3    조직형태별         개인사업체        -     12.5     29.5     37.0     21.0
# 7   종사자규모별        10~19인      0.6     10.6     41.7     33.9     13.2
# 17  산업대분류별  숙박 및 음식점업(I)        -      7.5     20.7     44.3     27.6
#
#          2021.14        2021.22
# 0          감소 이유          감소 이유
# 1   국내 수요(수주) 감소  코로나19 영향 매출감소
# 2           28.6           40.6
# 3           25.6           46.9
# 7           29.5           41.4
# 17           6.2           93.8

# %%
df3 = pd.read_csv('실내여가.csv',  encoding='cp949')
print(df3)
# Out:
#     행정구역별(1)   특성별(1)       특성별(2)         2022  2022.1  2022.2  \
# 0   행정구역별(1)   특성별(1)       특성별(2)  계_변화에 대한 견해  - 긍정적임  - 부정적임
# 1         전국       전체            계        100.0    76.0    24.0
# 2         전국    동·읍면부           동부        100.0    75.6    24.4
# 3         전국    동·읍면부          읍면부        100.0    78.2    21.8
# 4         전국       성별           남자        100.0    74.6    25.4
# ..       ...      ...          ...          ...     ...     ...
# 76        전국  연령*교육정도    60세 이상*고졸        100.0    73.4    26.6
# 77        전국  연령*교육정도  60세 이상*대졸이상        100.0    75.1    24.9
# 78        전국  연령*교육정도  65세 이상*중졸이하        100.0    73.6    26.4
# 79        전국  연령*교육정도    65세 이상*고졸        100.0    73.8    26.2
# 80        전국  연령*교육정도  65세 이상*대졸이상        100.0    74.8    25.2
#
#                   2022.3                  2022.4            2022.5  \
# 0   계_변화가 지속될 가능성에 대한 견해  - 코로나19 이전 상황으로 돌아갈 것임  - 현재 수준으로 유지될 것임
# ...

# %%
data3 = df3.loc[[0,1,4,5,7,8,51,52,53,54]]
#dataa3 = data3.iloc[:,[]]
print(data3)
# Out:
#     행정구역별(1)  특성별(1)     특성별(2)         2022  2022.1  2022.2  \
# 0   행정구역별(1)  특성별(1)     특성별(2)  계_변화에 대한 견해  - 긍정적임  - 부정적임
# 1         전국      전체          계        100.0    76.0    24.0
# 4         전국      성별         남자        100.0    74.6    25.4
# 5         전국      성별         여자        100.0    77.5    22.5
# 7         전국      연령     20∼29세        100.0    81.2    18.8
# 8         전국      연령     30∼39세        100.0    78.4    21.6
# 51        전국   연령*성별  20∼29세*남자        100.0    78.9    21.1
# 52        전국   연령*성별  20∼29세*여자        100.0    83.8    16.2
# 53        전국   연령*성별  30∼39세*남자        100.0    77.5    22.5
# 54        전국   연령*성별  30∼39세*여자        100.0    79.5    20.5
#
#                   2022.3                  2022.4            2022.5  \
# 0   계_변화가 지속될 가능성에 대한 견해  - 코로나19 이전 상황으로 돌아갈 것임  - 현재 수준으로 유지될 것임
# 1                  100.0                    38.7              47.0
# 4                  100.0                    40.0              45.8
# ...
